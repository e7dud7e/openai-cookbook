# %% [markdown]
# # Visualizing embeddings in 3D

# %% [markdown]
# The example uses [PCA](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html) to reduce the dimensionality fo the embeddings from 1536 to 3. Then we can visualize the data points in a 3D plot. The small dataset `dbpedia_samples.jsonl` is curated by randomly sampling 200 samples from [DBpedia validation dataset](https://www.kaggle.com/danofer/dbpedia-classes?select=DBPEDIA_val.csv).

# %% [markdown]
# ### 1. Load the dataset and query embeddings

# %%
import pandas as pd
samples = pd.read_json("data/dbpedia_samples.jsonl", lines=True)
categories = sorted(samples["category"].unique())
print("Categories of DBpedia samples:", samples["category"].value_counts())
samples.head()
# Out:
# Categories of DBpedia samples: Artist                    21
# Film                      19
# Plant                     19
# OfficeHolder              18
# Company                   17
# NaturalPlace              16
# Athlete                   16
# Village                   12
# WrittenWork               11
# Building                  11
# Album                     11
# Animal                    11
# EducationalInstitution    10
# MeanOfTransportation       8
# Name: category, dtype: int64
#                                                 text      category
# 0   Morada Limited is a textile company based in ...       Company
# 1   The Armenian Mirror-Spectator is a newspaper ...   WrittenWork
# 2   Mt. Kinka (金華山 Kinka-zan) also known as Kinka...  NaturalPlace
# 3   Planning the Play of a Bridge Hand is a book ...   WrittenWork
# 4   Wang Yuanping (born 8 December 1976) is a ret...       Athlete

# %%
from openai.embeddings_utils import get_embeddings
# NOTE: The following code will send a query of batch size 200 to /embeddings
matrix = get_embeddings(samples["text"].to_list(), engine="text-embedding-ada-002")

# %% [markdown]
# ### 2. Reduce the embedding dimensionality

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
vis_dims = pca.fit_transform(matrix)
samples["embed_vis"] = vis_dims.tolist()

# %% [markdown]
# ### 3. Plot the embeddings of lower dimensionality

# %%
# !pip install ipympl
# Out:
# Collecting ipympl
#   Downloading ipympl-0.9.3-py2.py3-none-any.whl (511 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.6/511.6 kB 7.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: matplotlib<4,>=3.4.0 in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from ipympl) (3.6.3)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from ipympl) (8.0.4)
# Requirement already satisfied: ipython<9 in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from ipympl) (8.12.0)
# Requirement already satisfied: traitlets<6 in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from ipympl) (5.7.1)
# Requirement already satisfied: ipython-genutils in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: pillow in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from ipympl) (9.4.0)
# Requirement already satisfied: numpy in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from ipympl) (1.24.2)
# Requirement already satisfied: pexpect>4.3 in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from ipython<9->ipympl) (4.8.0)
# Requirement already satisfied: pygments>=2.4.0 in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from ipython<9->ipympl) (2.15.1)
# Requirement already satisfied: matplotlib-inline in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from ipython<9->ipympl) (0.1.6)
# Requirement already satisfied: appnope in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from ipython<9->ipympl) (0.1.2)
# Requirement already satisfied: pickleshare in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from ipython<9->ipympl) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from ipython<9->ipympl) (0.18.1)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from ipython<9->ipympl) (3.0.36)
# Requirement already satisfied: stack-data in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: backcall in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: decorator in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from ipython<9->ipympl) (5.1.1)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (6.19.2)
# Requirement already satisfied: widgetsnbextension~=4.0 in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (4.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (4.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (23.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (8.1.0)
# Requirement already satisfied: psutil in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (5.9.0)
# Requirement already satisfied: tornado>=6.1 in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (6.2)
# Requirement already satisfied: comm>=0.1.1 in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.5.1)
# Requirement already satisfied: pyzmq>=17 in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (25.0.2)
# Requirement already satisfied: nest-asyncio in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.5.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from pexpect>4.3->ipython<9->ipympl) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython<9->ipympl) (0.2.5)
# Requirement already satisfied: six>=1.5 in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.4.0->ipympl) (1.16.0)
# Requirement already satisfied: asttokens in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl) (0.2.2)
# Requirement already satisfied: executing in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (5.3.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/edwardshyu/miniconda3/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (2.5.2)
# Installing collected packages: ipympl
# Successfully installed ipympl-0.9.3

# %%
# %matplotlib widget
import matplotlib.pyplot as plt

# %%
import numpy as np

fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot(projection='3d')
cmap = plt.get_cmap("tab20")

# Plot each sample category individually such that we can set label name.
for i, cat in enumerate(categories):
    sub_matrix = np.array(samples[samples["category"] == cat]["embed_vis"].to_list())
    x=sub_matrix[:, 0]
    y=sub_matrix[:, 1]
    z=sub_matrix[:, 2]
    colors = [cmap(i/len(categories))] * len(sub_matrix)
    ax.scatter(x, y, zs=z, zdir='z', c=colors, label=cat)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.legend(bbox_to_anchor=(1.1, 1))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
